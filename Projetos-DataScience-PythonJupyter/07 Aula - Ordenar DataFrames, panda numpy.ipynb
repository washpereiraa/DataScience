# %%
import pandas as panda
import numpy

#lendo o arquivo e ja renomeando as colunas 
nomeColunas = ['star_rating', 'title', 'content_rating', 'genre', 'durating', 'actors_list']

dadoFilmes = panda.read_csv('C:\GIT\DataScience\Datasets\movies.csv', header=0, names = nomeColunas)
dadoFilmes.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# durating            int64
# actors_list        object
# dtype: object

# %%
#ORDENANDO DADOS DOS FILMES POR TITULO

dadoFilmes.title.sort_values().head() # se tirar o metodo .head() tras todos os filmes]
#retorno do sort valeues é um serie
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
# Name: title, dtype: object

# %%
#Invetendo a ordem

dadoFilmes.title.sort_values(ascending = False)
# Out:
# 864                    [Rec]
# 526                     Zulu
# 615               Zombieland
# 677                   Zodiac
# 955         Zero Dark Thirty
#                ...
# 110    2001: A Space Odyssey
# 698                127 Hours
# 201         12 Years a Slave
# 5               12 Angry Men
# 542     (500) Days of Summer
# Name: title, Length: 979, dtype: object

# %%
#Ordenar por titulo no proprio DataFrame

dadoFilmes.sort_values('title')
# Out:
#      star_rating                  title content_rating      genre  durating  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# ..           ...                    ...            ...        ...       ...
# 955          7.4       Zero Dark Thirty              R      Drama       157
# 677          7.7                 Zodiac              R      Crime       157
# 615          7.7             Zombieland              R     Comedy        88
# 526          7.8                   Zulu        UNRATED      Drama       138
# 864          7.5                  [Rec]              R     Horror        78
#
#                                            actors_list
# ...

# %%
dadoFilmes.sort_values(['title','durating'], ascending=False)
# Out:
#      star_rating                  title content_rating      genre  durating  \
# 864          7.5                  [Rec]              R     Horror        78
# 526          7.8                   Zulu        UNRATED      Drama       138
# 615          7.7             Zombieland              R     Comedy        88
# 677          7.7                 Zodiac              R      Crime       157
# 955          7.4       Zero Dark Thirty              R      Drama       157
# ..           ...                    ...            ...        ...       ...
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# 698          7.6              127 Hours              R  Adventure        94
# 201          8.1       12 Years a Slave              R  Biography       134
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
#
#                                            actors_list
# ...

# %%
dadoFilmes = dadoFilmes.drop([0], axis = 0)
dadoFilmes
# Out:
#      star_rating                                            title  \
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  durating  \
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# ...

# %%
def tratarTempo(duracao):
    import re
    match = re.compile(r'"(.*)(.0)"')
    duracao = match.sub(r'"\1"', duracao)
    return duracao

#tratarTempo(dadoFilmes.durating[1])

# %%
#for tempo in dadoFilmes.durating[1:]:
   # dadoFilmes.durating[tempo] = tratarTempo(tempo)

#dadoFilmes.durating

# %%
#for indice, duracao in enumerate(dadoFilmes['durating']):
 #       dadoFilmes['durating'][indice] = float(duracao)

# %%
dadoFilmes.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# durating            int64
# actors_list        object
# dtype: object

# %%
#CRIANDO FILTROS PARA TRAZER OS RESULTADOS

boleanos = []

for item in dadoFilmes.durating:
    if item >= 200:
        boleanos.append(True)
    else:
        boleanos.append(False)

# %%
len(boleanos)
# Out:
# 978

# %%
dadoFilmes.shape
# Out:
# (978, 6)

# %%
duracao = panda.Series(boleanos)

# %%
#aplicando uma serie booleana do DataFrame
#dadoFilmes[duracao]

# %%
dadoFilmes[dadoFilmes.durating >= 180].head()
# Out:
#     star_rating                                          title content_rating  \
# 2           9.1                         The Godfather: Part II              R
# 7           8.9  The Lord of the Rings: The Return of the King          PG-13
# 8           8.9                               Schindler's List              R
# 17          8.7                                  Seven Samurai        UNRATED
# 40          8.5                                 The Green Mile              R
#
#         genre  durating                                        actors_list
# 2       Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7   Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 8   Biography       195  [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# 17      Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 40      Crime       189  [u'Tom Hanks', u'Michael Clarke Duncan', u'Dav...

# %%
genero = dadoFilmes[dadoFilmes.durating >= 200].genre.head(10)
genero
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# Name: genre, dtype: object

# %%
#melhor forma de aplicar filtros = LOC
dadoFilmes.loc[dadoFilmes.durating >= 180].head()
